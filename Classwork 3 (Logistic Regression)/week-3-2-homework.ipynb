# %% [markdown]
# ## Week 3-2 - Logistic Regression - homework
#
# In this assignment, you'll do a logistic regression to look at the effect of sex and class on survival on the titanic, by computing odds ratios.
#
# Some references:
#
# - [What are odds vs. probability?](https://towcenter.gitbooks.io/curious-journalist-s-guide-to-data/content/analysis/counting_possible_worlds.html)
# - An example of a story based on an odds ratio: [Deadly force in black and white](https://www.propublica.org/article/deadly-force-in-black-and-white)
# - [Building A Logistic Regression in Python, Step by Step](https://towardsdatascience.com/building-a-logistic-regression-in-python-step-by-step-becd4d56c9c8) Here it's being used for prediction by looking at the output, whereas we are using it for explanation by looking at the coefficient, but setting it up works the same.
# - [How do I interpret odds ratios in logistic regression?](https://stats.idre.ucla.edu/other/mult-pkg/faq/general/faq-how-do-i-interpret-odds-ratios-in-logistic-regression/) This one's a little more technical, but has good examples.

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
# %matplotlib inline

# %% [markdown]
# ### Load the data
#
# Read in the `titanic.csv` data set again.

# %%
# Load titanic.csv
titanic = pd.read_csv('titanic.csv')
titanic
# Out:
#      pclass  survived                                              name  \
# 0       1st         1                      Allen, Miss Elisabeth Walton
# 1       1st         0                       Allison, Miss Helen Loraine
# 2       1st         0               Allison, Mr Hudson Joshua Creighton
# 3       1st         0   Allison, Mrs Hudson J.C. (Bessie Waldo Daniels)
# 4       1st         1                     Allison, Master Hudson Trevor
# 5       1st         1                                Anderson, Mr Harry
# 6       1st         1                  Andrews, Miss Kornelia Theodosia
# 7       1st         0                            Andrews, Mr Thomas, jr
# 8       1st         1      Appleton, Mrs Edward Dale (Charlotte Lamson)
# 9       1st         0                            Artagaveytia, Mr Ramon
# 10      1st         0                         Astor, Colonel John Jacob
# 11      1st         1  Astor, Mrs John Jacob (Madeleine Talmadge Force)
# 12      1st         1                      Aubert, Mrs Leontine Pauline
# 13      1st         1                         Barkworth, Mr Algernon H.
# 14      1st         0                               Baumann, Mr John D.
# 15      1st         1    Baxter, Mrs James (Helene DeLaudeniere Chaput)
# 16      1st         0                           Baxter, Mr Quigg Edmond
# 17      1st         0                               Beattie, Mr Thomson
# 18      1st         1                      Beckwith, Mr Richard Leonard
# 19      1st         1   Beckwith, Mrs Richard Leonard (Sallie Monypeny)
# 20      1st         1                              Behr, Mr Karl Howell
# 21      1st         0                                Birnbaum, Mr Jakob
# 22      1st         1                           Bishop, Mr Dickinson H.
# 23      1st         1           Bishop, Mrs Dickinson H. (Helen Walton)
# 24      1st         1           Bjornstrm-Steffansson, Mr Mauritz Hakan
# 25      1st         0                       Blackwell, Mr Stephen Weart
# 26      1st         1                                   Blank, Mr Henry
# 27      1st         1                            Bonnell, Miss Caroline
# 28      1st         1                           Bonnell, Miss Elizabeth
# 29      1st         0                           Borebank, Mr John James
# ...     ...       ...                                               ...
# 1283    3rd         0               Vestrom, Miss Hulda Amanda Adolfina
# 1284    3rd         0                                    Vonk, Mr Jenko
# 1285    3rd         0                                Ware, Mr Frederick
# 1286    3rd         0                        Warren, Mr Charles William
# 1287    3rd         0                                  Wazli, Mr Yousif
# 1288    3rd         0                                  Webber, Mr James
# 1289    3rd         1                     Wennerstrom, Mr August Edvard
# 1290    3rd         0                                Wenzel, Mr Linhart
# 1291    3rd         0                        Widegren, Mr Charles Peter
# 1292    3rd         0                          Wiklund, Mr Jacob Alfred
# 1293    3rd         1                                 Wilkes, Mrs Ellen
# 1294    3rd         0                                  Willer, Mr Aaron
# 1295    3rd         0                                 Willey, Mr Edward
# 1296    3rd         0                          Williams, Mr Howard Hugh
# 1297    3rd         0                               Williams, Mr Leslie
# 1298    3rd         0                                Windelov, Mr Einar
# 1299    3rd         0                                   Wirz, Mr Albert
# 1300    3rd         0                             Wiseman, Mr Phillippe
# 1301    3rd         0                           Wittevrongel, Mr Camiel
# 1302    3rd         1                                 Yalsevac, Mr Ivan
# 1303    3rd         0                                Yasbeck, Mr Antoni
# 1304    3rd         1                               Yasbeck, Mrs Antoni
# 1305    3rd         0                                Youssef, Mr Gerios
# 1306    3rd         0                               Zabour, Miss Hileni
# 1307    3rd         0                               Zabour, Miss Tamini
# 1308    3rd         0                                Zakarian, Mr Artun
# 1309    3rd         0                            Zakarian, Mr Maprieder
# 1310    3rd         0                                   Zenn, Mr Philip
# 1311    3rd         0                                     Zievens, Rene
# 1312    3rd         0                                    Zimmerman, Leo
#
#           age     embarked                           home.dest     room  \
# 0     29.0000  Southampton                        St Louis, MO      B-5
# 1      2.0000  Southampton     Montreal, PQ / Chesterville, ON      C26
# 2     30.0000  Southampton     Montreal, PQ / Chesterville, ON      C26
# 3     25.0000  Southampton     Montreal, PQ / Chesterville, ON      C26
# 4      0.9167  Southampton     Montreal, PQ / Chesterville, ON      C22
# 5     47.0000  Southampton                        New York, NY     E-12
# 6     63.0000  Southampton                          Hudson, NY      D-7
# 7     39.0000  Southampton                         Belfast, NI     A-36
# 8     58.0000  Southampton                 Bayside, Queens, NY    C-101
# 9     71.0000    Cherbourg                 Montevideo, Uruguay      NaN
# 10    47.0000    Cherbourg                        New York, NY      NaN
# 11    19.0000    Cherbourg                        New York, NY      NaN
# 12        NaN    Cherbourg                       Paris, France     B-35
# 13        NaN  Southampton                       Hessle, Yorks     A-23
# 14        NaN  Southampton                        New York, NY      NaN
# 15    50.0000    Cherbourg                        Montreal, PQ  B-58/60
# 16    24.0000    Cherbourg                        Montreal, PQ  B-58/60
# 17    36.0000    Cherbourg                        Winnipeg, MN      C-6
# 18    37.0000  Southampton                        New York, NY     D-35
# 19    47.0000  Southampton                        New York, NY     D-35
# 20    26.0000    Cherbourg                        New York, NY    C-148
# 21    25.0000    Cherbourg                   San Francisco, CA      NaN
# 22    25.0000    Cherbourg                        Dowagiac, MI     B-49
# 23    19.0000    Cherbourg                        Dowagiac, MI     B-49
# 24    28.0000  Southampton  Stockholm, Sweden / Washington, DC      NaN
# 25    45.0000  Southampton                         Trenton, NJ      NaN
# 26    39.0000    Cherbourg                      Glen Ridge, NJ     A-31
# 27    30.0000  Southampton                      Youngstown, OH      C-7
# 28    58.0000  Southampton   Birkdale, England Cleveland, Ohio    C-103
# 29        NaN  Southampton               London / Winnipeg, MB   D-21/2
# ...       ...          ...                                 ...      ...
# 1283      NaN          NaN                                 NaN      NaN
# 1284      NaN          NaN                                 NaN      NaN
# 1285      NaN          NaN                                 NaN      NaN
# 1286      NaN          NaN                                 NaN      NaN
# 1287      NaN          NaN                                 NaN      NaN
# 1288      NaN          NaN                                 NaN      NaN
# 1289      NaN          NaN                                 NaN      NaN
# 1290      NaN          NaN                                 NaN      NaN
# 1291      NaN          NaN                                 NaN      NaN
# 1292      NaN          NaN                                 NaN      NaN
# 1293      NaN          NaN                                 NaN      NaN
# 1294      NaN          NaN                                 NaN      NaN
# 1295      NaN          NaN                                 NaN      NaN
# 1296      NaN          NaN                                 NaN      NaN
# 1297      NaN          NaN                                 NaN      NaN
# 1298      NaN          NaN                                 NaN      NaN
# 1299      NaN          NaN                                 NaN      NaN
# 1300      NaN          NaN                                 NaN      NaN
# 1301      NaN          NaN                                 NaN      NaN
# 1302      NaN          NaN                                 NaN      NaN
# 1303      NaN          NaN                                 NaN      NaN
# 1304      NaN          NaN                                 NaN      NaN
# 1305      NaN          NaN                                 NaN      NaN
# 1306      NaN          NaN                                 NaN      NaN
# 1307      NaN          NaN                                 NaN      NaN
# 1308      NaN          NaN                                 NaN      NaN
# 1309      NaN          NaN                                 NaN      NaN
# 1310      NaN          NaN                                 NaN      NaN
# 1311      NaN          NaN                                 NaN      NaN
# 1312      NaN          NaN                                 NaN      NaN
#
#                  ticket  boat  gender
# 0            24160 L221     2  female
# 1                   NaN   NaN  female
# 2                   NaN  -135    male
# 3                   NaN   NaN  female
# 4                   NaN    11    male
# 5                   NaN     3    male
# 6             13502 L77    10  female
# 7                   NaN   NaN    male
# 8                   NaN     2  female
# 9                   NaN   -22    male
# 10    17754 L224 10s 6d  -124    male
# 11    17754 L224 10s 6d     4  female
# 12         17477 L69 6s     9  female
# 13                  NaN     B    male
# 14                  NaN   NaN    male
# 15                  NaN     6  female
# 16                  NaN   NaN    male
# 17                  NaN   NaN    male
# 18                  NaN     5    male
# 19                  NaN     5  female
# 20                  NaN     5    male
# 21                  NaN  -148    male
# 22                  NaN     7    male
# 23                  NaN     7  female
# 24                          D    male
# 25                  NaN  -241    male
# 26                  NaN     7    male
# 27                  NaN     8  female
# 28                  NaN     8  female
# 29                  NaN   NaN    male
# ...                 ...   ...     ...
# 1283                NaN   NaN  female
# 1284                NaN   NaN    male
# 1285                NaN   NaN    male
# 1286                NaN   NaN    male
# 1287                NaN   NaN    male
# 1288                NaN   NaN    male
# 1289                NaN   NaN    male
# 1290                NaN   NaN    male
# 1291                NaN   NaN    male
# 1292                NaN   NaN    male
# 1293                NaN   NaN  female
# 1294                NaN   NaN    male
# 1295                NaN   NaN    male
# 1296                NaN   NaN    male
# 1297                NaN   NaN    male
# 1298                NaN   NaN    male
# 1299                NaN   NaN    male
# 1300                NaN   NaN    male
# 1301                NaN   NaN    male
# 1302                NaN   NaN    male
# 1303                NaN   NaN    male
# 1304                NaN   NaN  female
# 1305                NaN   NaN    male
# 1306                NaN   NaN  female
# 1307                NaN   NaN  female
# 1308                NaN   NaN    male
# 1309                NaN   NaN    male
# 1310                NaN   NaN    male
# 1311                NaN   NaN  female
# 1312                NaN   NaN    male
#
# [1313 rows x 10 columns]

# %% [markdown]
# The first thing we need to do is code the pclass and gender variables numerically. Let's use the following scheme:
# - pclass: 1,2,3
# - gender: 0=male, 1=female, and let's call the column called "female" to remind us which is which

# %%
# recode the pclass and gender variables so they are numeric
titanic = titanic.replace({'1st':1, '2nd':2, '3rd':3, 'female':1, 'male':0})
titanic
# Out:
#       pclass  survived                                              name  \
# 0          1         1                      Allen, Miss Elisabeth Walton
# 1          1         0                       Allison, Miss Helen Loraine
# 2          1         0               Allison, Mr Hudson Joshua Creighton
# 3          1         0   Allison, Mrs Hudson J.C. (Bessie Waldo Daniels)
# 4          1         1                     Allison, Master Hudson Trevor
# 5          1         1                                Anderson, Mr Harry
# 6          1         1                  Andrews, Miss Kornelia Theodosia
# 7          1         0                            Andrews, Mr Thomas, jr
# 8          1         1      Appleton, Mrs Edward Dale (Charlotte Lamson)
# 9          1         0                            Artagaveytia, Mr Ramon
# 10         1         0                         Astor, Colonel John Jacob
# 11         1         1  Astor, Mrs John Jacob (Madeleine Talmadge Force)
# 12         1         1                      Aubert, Mrs Leontine Pauline
# 13         1         1                         Barkworth, Mr Algernon H.
# 14         1         0                               Baumann, Mr John D.
# 15         1         1    Baxter, Mrs James (Helene DeLaudeniere Chaput)
# 16         1         0                           Baxter, Mr Quigg Edmond
# 17         1         0                               Beattie, Mr Thomson
# 18         1         1                      Beckwith, Mr Richard Leonard
# 19         1         1   Beckwith, Mrs Richard Leonard (Sallie Monypeny)
# 20         1         1                              Behr, Mr Karl Howell
# 21         1         0                                Birnbaum, Mr Jakob
# 22         1         1                           Bishop, Mr Dickinson H.
# 23         1         1           Bishop, Mrs Dickinson H. (Helen Walton)
# 24         1         1           Bjornstrm-Steffansson, Mr Mauritz Hakan
# 25         1         0                       Blackwell, Mr Stephen Weart
# 26         1         1                                   Blank, Mr Henry
# 27         1         1                            Bonnell, Miss Caroline
# 28         1         1                           Bonnell, Miss Elizabeth
# 29         1         0                           Borebank, Mr John James
# ...      ...       ...                                               ...
# 1283       3         0               Vestrom, Miss Hulda Amanda Adolfina
# 1284       3         0                                    Vonk, Mr Jenko
# 1285       3         0                                Ware, Mr Frederick
# 1286       3         0                        Warren, Mr Charles William
# 1287       3         0                                  Wazli, Mr Yousif
# 1288       3         0                                  Webber, Mr James
# 1289       3         1                     Wennerstrom, Mr August Edvard
# 1290       3         0                                Wenzel, Mr Linhart
# 1291       3         0                        Widegren, Mr Charles Peter
# 1292       3         0                          Wiklund, Mr Jacob Alfred
# 1293       3         1                                 Wilkes, Mrs Ellen
# 1294       3         0                                  Willer, Mr Aaron
# 1295       3         0                                 Willey, Mr Edward
# 1296       3         0                          Williams, Mr Howard Hugh
# 1297       3         0                               Williams, Mr Leslie
# 1298       3         0                                Windelov, Mr Einar
# 1299       3         0                                   Wirz, Mr Albert
# 1300       3         0                             Wiseman, Mr Phillippe
# 1301       3         0                           Wittevrongel, Mr Camiel
# 1302       3         1                                 Yalsevac, Mr Ivan
# 1303       3         0                                Yasbeck, Mr Antoni
# 1304       3         1                               Yasbeck, Mrs Antoni
# 1305       3         0                                Youssef, Mr Gerios
# 1306       3         0                               Zabour, Miss Hileni
# 1307       3         0                               Zabour, Miss Tamini
# 1308       3         0                                Zakarian, Mr Artun
# 1309       3         0                            Zakarian, Mr Maprieder
# 1310       3         0                                   Zenn, Mr Philip
# 1311       3         0                                     Zievens, Rene
# 1312       3         0                                    Zimmerman, Leo
#
#           age     embarked                           home.dest     room  \
# 0     29.0000  Southampton                        St Louis, MO      B-5
# 1      2.0000  Southampton     Montreal, PQ / Chesterville, ON      C26
# 2     30.0000  Southampton     Montreal, PQ / Chesterville, ON      C26
# 3     25.0000  Southampton     Montreal, PQ / Chesterville, ON      C26
# 4      0.9167  Southampton     Montreal, PQ / Chesterville, ON      C22
# 5     47.0000  Southampton                        New York, NY     E-12
# 6     63.0000  Southampton                          Hudson, NY      D-7
# 7     39.0000  Southampton                         Belfast, NI     A-36
# 8     58.0000  Southampton                 Bayside, Queens, NY    C-101
# 9     71.0000    Cherbourg                 Montevideo, Uruguay      NaN
# 10    47.0000    Cherbourg                        New York, NY      NaN
# 11    19.0000    Cherbourg                        New York, NY      NaN
# 12        NaN    Cherbourg                       Paris, France     B-35
# 13        NaN  Southampton                       Hessle, Yorks     A-23
# 14        NaN  Southampton                        New York, NY      NaN
# 15    50.0000    Cherbourg                        Montreal, PQ  B-58/60
# 16    24.0000    Cherbourg                        Montreal, PQ  B-58/60
# 17    36.0000    Cherbourg                        Winnipeg, MN      C-6
# 18    37.0000  Southampton                        New York, NY     D-35
# 19    47.0000  Southampton                        New York, NY     D-35
# 20    26.0000    Cherbourg                        New York, NY    C-148
# 21    25.0000    Cherbourg                   San Francisco, CA      NaN
# 22    25.0000    Cherbourg                        Dowagiac, MI     B-49
# 23    19.0000    Cherbourg                        Dowagiac, MI     B-49
# 24    28.0000  Southampton  Stockholm, Sweden / Washington, DC      NaN
# 25    45.0000  Southampton                         Trenton, NJ      NaN
# 26    39.0000    Cherbourg                      Glen Ridge, NJ     A-31
# 27    30.0000  Southampton                      Youngstown, OH      C-7
# 28    58.0000  Southampton   Birkdale, England Cleveland, Ohio    C-103
# 29        NaN  Southampton               London / Winnipeg, MB   D-21/2
# ...       ...          ...                                 ...      ...
# 1283      NaN          NaN                                 NaN      NaN
# 1284      NaN          NaN                                 NaN      NaN
# 1285      NaN          NaN                                 NaN      NaN
# 1286      NaN          NaN                                 NaN      NaN
# 1287      NaN          NaN                                 NaN      NaN
# 1288      NaN          NaN                                 NaN      NaN
# 1289      NaN          NaN                                 NaN      NaN
# 1290      NaN          NaN                                 NaN      NaN
# 1291      NaN          NaN                                 NaN      NaN
# 1292      NaN          NaN                                 NaN      NaN
# 1293      NaN          NaN                                 NaN      NaN
# 1294      NaN          NaN                                 NaN      NaN
# 1295      NaN          NaN                                 NaN      NaN
# 1296      NaN          NaN                                 NaN      NaN
# 1297      NaN          NaN                                 NaN      NaN
# 1298      NaN          NaN                                 NaN      NaN
# 1299      NaN          NaN                                 NaN      NaN
# 1300      NaN          NaN                                 NaN      NaN
# 1301      NaN          NaN                                 NaN      NaN
# 1302      NaN          NaN                                 NaN      NaN
# 1303      NaN          NaN                                 NaN      NaN
# 1304      NaN          NaN                                 NaN      NaN
# 1305      NaN          NaN                                 NaN      NaN
# 1306      NaN          NaN                                 NaN      NaN
# 1307      NaN          NaN                                 NaN      NaN
# 1308      NaN          NaN                                 NaN      NaN
# 1309      NaN          NaN                                 NaN      NaN
# 1310      NaN          NaN                                 NaN      NaN
# 1311      NaN          NaN                                 NaN      NaN
# 1312      NaN          NaN                                 NaN      NaN
#
#                  ticket  boat  gender
# 0            24160 L221     2       1
# 1                   NaN   NaN       1
# 2                   NaN  -135       0
# 3                   NaN   NaN       1
# 4                   NaN    11       0
# 5                   NaN     3       0
# 6             13502 L77    10       1
# 7                   NaN   NaN       0
# 8                   NaN     2       1
# 9                   NaN   -22       0
# 10    17754 L224 10s 6d  -124       0
# 11    17754 L224 10s 6d     4       1
# 12         17477 L69 6s     9       1
# 13                  NaN     B       0
# 14                  NaN   NaN       0
# 15                  NaN     6       1
# 16                  NaN   NaN       0
# 17                  NaN   NaN       0
# 18                  NaN     5       0
# 19                  NaN     5       1
# 20                  NaN     5       0
# 21                  NaN  -148       0
# 22                  NaN     7       0
# 23                  NaN     7       1
# 24                          D       0
# 25                  NaN  -241       0
# 26                  NaN     7       0
# 27                  NaN     8       1
# 28                  NaN     8       1
# 29                  NaN   NaN       0
# ...                 ...   ...     ...
# 1283                NaN   NaN       1
# 1284                NaN   NaN       0
# 1285                NaN   NaN       0
# 1286                NaN   NaN       0
# 1287                NaN   NaN       0
# 1288                NaN   NaN       0
# 1289                NaN   NaN       0
# 1290                NaN   NaN       0
# 1291                NaN   NaN       0
# 1292                NaN   NaN       0
# 1293                NaN   NaN       1
# 1294                NaN   NaN       0
# 1295                NaN   NaN       0
# 1296                NaN   NaN       0
# 1297                NaN   NaN       0
# 1298                NaN   NaN       0
# 1299                NaN   NaN       0
# 1300                NaN   NaN       0
# 1301                NaN   NaN       0
# 1302                NaN   NaN       0
# 1303                NaN   NaN       0
# 1304                NaN   NaN       1
# 1305                NaN   NaN       0
# 1306                NaN   NaN       1
# 1307                NaN   NaN       1
# 1308                NaN   NaN       0
# 1309                NaN   NaN       0
# 1310                NaN   NaN       0
# 1311                NaN   NaN       1
# 1312                NaN   NaN       0
#
# [1313 rows x 10 columns]

# %% [markdown]
# ### 2. Looking at one variable at a time
#
# First, do a logistic regression of the `female` variable alone. Below is some code that will help you plot the result.

# %%
# function to plot single variable logistic regression results
def plot_logistic_regression(x, y, lm):

    # plot original data
    plt.scatter(x=x,y=y)

    # Now plot the prediction of the fitted model
    predict_x = np.linspace(x.min(), x.max(), 10).reshape(-1, 1) # some evenly spaced points to predict
    predict_y = lm.predict_proba(predict_x)[:,1] #  probability of result = true
    plt.plot(predict_x, predict_y, '-', color='m')

# %%
# Do a logistic regression of survived against pclass
x = titanic[['survived']].values
y = titanic[['pclass']].values
titanic.plot(kind='scatter',x='survived',y='pclass')

# %%
from sklearn.linear_model import LinearRegression,LogisticRegression

lm = LinearRegression()
lm.fit(x,y)
titanic.plot(kind='scatter',x='survived',y='pclass')
plt.plot(x,lm.predict(x),'-',color='m')
# Out:
# /Users/linleysanders/.pyenv/versions/3.6.4/lib/python3.6/site-packages/sklearn/linear_model/base.py:509: RuntimeWarning: internal gelsd driver lwork query error, required iwork dimension not returned. This is likely the result of LAPACK bug 0038, fixed in LAPACK 3.2.2 (released July 21, 2010). Falling back to 'gelss' driver.
#   linalg.lstsq(X, y)

# %%
# Do a logistic regression of survived against pclass
x = titanic[['survived']].values
y = titanic[['gender']].values
titanic.plot(kind='scatter',x='survived',y='gender')

from sklearn.linear_model import LinearRegression,LogisticRegression

lm = LinearRegression()
lm.fit(x,y)
titanic.plot(kind='scatter',x='survived',y='gender')
plt.plot(x,lm.predict(x),'-',color='m')

# %% [markdown]
# The plot may not look like much, because there are only two values of `female` so most of the dots are on top of eachother. But the regression should capture the fact that more women survived than men, by sloping upward.
#
# Most of the information will be in the resulting odds ratio. This will tell us how much the odds of surivial differ between men and women. Compute it now.

# %%
# What is the odds ratio of on the class variable?
cv = pd.crosstab(titanic.pclass, titanic.survived)
cv
# Out:
# survived    0    1
# pclass
# 1         129  193
# 2         161  119
# 3         574  137

# %%
# odds of surving if you were in first class
first_odds = cv[1][1] / cv[0][1]
first_odds
# Out:
# 1.496124031007752

# %%
# odds of surving if you were in second class
second_odds = cv[1][2] / cv[0][2]
second_odds
# Out:
# 0.7391304347826086

# %%
# odds of surving if you were in third class
third_odds = cv[1][3] / cv[0][3]
third_odds
# Out:
# 0.23867595818815332

# %%
# What is the odds ratio of on the class variable?
gv = pd.crosstab(titanic.gender, titanic.survived)
gv
# Out:
# survived    0    1
# gender
# 0         708  142
# 1         156  307

# %% [markdown]
# ### 3. Looking at two variables at a time
#
# We know from the earlier assignment that class also affects survival, so let's add that to our model. Compute a logistic regression on the variables `pclass` and `female`.

# %%
# Logistic regression on two variables

# %% [markdown]
# Now compute the odds ratio on each variable. You can print it out slightly prettier by using the trick in the class where we changed it into a dataframe.

# %%
# print out the odds ratios for each variable

# %% [markdown]
# ### 4. What does this mean
#
# What is the odds ratio on the `pclass` variable? What happens to the odds of survival when we move from 1st to 2nd or from 2nd to 3rd class?

# %% [markdown]
# The odds ratio on pclass is 0.36, meaning that the odds of survival decrease by about three times when we move from 1st to 2nd class, and again from 2nd to 3rd class.

# %% [markdown]
# The odds ratio on the `female` variable changed when we accounted for passenger class. Which direction, and what does this mean?

# %% [markdown]
# The odds ratio on `female` changed from 9.3 to 10.7. This means that when we are careful to compare the surivial rates of the sexes between passengers of the same class, we can see that women have even better odds of survival than it first appears. The number changes because the odds of surviving are lower in lower passenger classes, and those classes have more people in them. So when we only compare passengers within the same class, being female has an even greater advantage.

# %% [markdown]
# ## Bonus: How much effect did opinion of Obamacare have in the 2016 election?
#
# Let's look at votes for Trump in the ANES data again. Try it on the following columns:
#
# - Who did you vote for? This will be our dependent variable
# - Do you approve or disapprove of Obamacare?
# - What political party are you registered for?
#
# Start by doing a one variable logistic regression on vote vs. health care. Then add in political party, so that we are comparing the effect of opinion on health care only within voters who are registered to the same party. What happens to the odds ratio on the health care variable when we take into account which party they are registered to? Why?

# %%
# The columns we'll use
voted_col = 'V162034a' # 1=Clinton, 2=Trump, 3=Johnson, 4=Stein, negative numbers = didn't vote or won't say
health_care_col = 'V161085' # pre-election survey. 1=approve, 2=dissaprove,  negative numbers = didn't vote or won't say
registered_col = 'V161019' # 1=democratic, 2=republican, 3=none, 4=other, negative = not applicable or refused

# %%
# load the data and keep only the columns we need

# %%
# throw out all rows where:
# - didn't vote Dem or GOP
# - wasn't registered demo or GOP 
# - answer on health care question is not approve or disaprove

# %%
# Recode each variable so it's 0-1 instead of 1-2

# %%
# Do a single variable logistic regression of vote on health care, and plot

# %%
# What is the odds ratio of voting for Trump?
# That is, starting with the odds of voting for Trump if you approve of Obamacare,  
# how do the odds change if you dissaprove of Obamacare?

# %%
# Do a multiple variable logistic regression of vote on health care and party registration

# %%
# What is the odds ratio of voting for Trump if you dissaprove of Obamacare now?
# What is the odds ratio of voting for Trump if you are a registered Republican?

# %% [markdown]
# ### Explain what you've learned from the single and multiple variable regression

# %% [markdown]
# What happens to the odds ratio on the health care variable when we take into account which party they are registered to? Why?
